# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#For Ishmam:
dataset_path="/content/drive/MyDrive/CSE422-17 IBU/Lab Assignments/Final AI Project/movie_ratings_dataset.csv"

movie_rating_dataframe = pd.read_csv(dataset_path)
movie_rating_dataframe.head(10)
# Out:
#      Genre  Director_Popularity  Budget_MillionUSD  Runtime_Minutes  \
# 0   Sci-Fi                 5.80             134.63            141.0
# 1   Action                 2.27             220.47             98.0
# 2   Horror                 1.23              52.79            160.0
# 3   Action                 8.17              86.41            153.0
# 4  Romance                 6.40             259.57            134.0
# 5   Horror                 7.40             265.65              NaN
# 6   Horror                 3.73              14.44              NaN
# 7   Sci-Fi                 5.59              51.26            129.0
# 8    Drama                 7.72              36.12            144.0
# 9   Comedy                 5.16              54.73             82.0
#
#    Release_Year  Num_Main_Actors  Avg_Actor_Popularity Has_Famous_Producer  \
# 0           NaN              1.0                  2.72                  No
# 1        2006.0              1.0                  3.46                 Yes
# 2        2010.0              2.0                   NaN                 NaN
# 3        2022.0              4.0                  5.21                 NaN
# 4        1986.0              1.0                  8.72                 Yes
# 5        2024.0              3.0                  4.08                 Yes
# 6        1983.0              1.0                  3.40                  No
# 7        1993.0              4.0                   NaN                  No
# 8        2021.0              NaN                  9.20                  No
# 9        2021.0              3.0                  1.26                 Yes
#
#    Num_Awards_Won  Marketing_Spend_MillionUSD Is_Sequel Rating_Category
# 0             9.0                       25.48        No       Excellent
# 1            17.0                        9.13       Yes       Excellent
# 2            43.0                        6.16        No       Excellent
# 3             7.0                        2.99        No            Good
# 4            25.0                        0.89        No       Excellent
# 5             NaN                       43.91        No            Good
# 6            23.0                       40.45        No         Average
# 7             2.0                       28.39       Yes            Poor
# 8            37.0                       49.94        No         Average
# 9             1.0                       47.65       Yes       Excellent

# %%
#Dataset loading
print(movie_rating_dataframe)
print ('Shape of the dataset is {}. This dataset contains {} rows and {} columns.'.format(movie_rating_dataframe.shape,movie_rating_dataframe.shape[0],movie_rating_dataframe.shape[1]))
# Out:
#         Genre  Director_Popularity  Budget_MillionUSD  Runtime_Minutes  \
# 0      Sci-Fi                 5.80             134.63            141.0
# 1      Action                 2.27             220.47             98.0
# 2      Horror                 1.23              52.79            160.0
# 3      Action                 8.17              86.41            153.0
# 4     Romance                 6.40             259.57            134.0
# ...       ...                  ...                ...              ...
# 1195    Drama                 3.54             288.86            167.0
# 1196   Comedy                  NaN              22.49            179.0
# 1197   Comedy                 2.07              81.23            108.0
# 1198   Horror                 7.80              24.98            139.0
# 1199   Comedy                 1.88                NaN            108.0
#
#       Release_Year  Num_Main_Actors  Avg_Actor_Popularity Has_Famous_Producer  \
# 0              NaN              1.0                  2.72                  No
# 1           2006.0              1.0                  3.46                 Yes
# 2           2010.0              2.0                   NaN                 NaN
# 3           2022.0              4.0                  5.21                 NaN
# 4           1986.0              1.0                  8.72                 Yes
# ...            ...              ...                   ...                 ...
# 1195        2016.0              3.0                  6.35                 Yes
# 1196        1990.0              4.0                  8.95                 Yes
# 1197        2023.0              2.0                  9.20                  No
# 1198        2001.0              2.0                  9.63                  No
# 1199        2020.0              2.0                  7.96                 Yes
#
#       Num_Awards_Won  Marketing_Spend_MillionUSD Is_Sequel Rating_Category
# 0                9.0                       25.48        No       Excellent
# 1               17.0                        9.13       Yes       Excellent
# 2               43.0                        6.16        No       Excellent
# 3                7.0                        2.99        No            Good
# 4               25.0                        0.89        No       Excellent
# ...              ...                         ...       ...             ...
# 1195            46.0                       17.66       NaN       Excellent
# 1196            17.0                       10.54       NaN         Average
# 1197            46.0                       38.61        No         Average
# 1198            19.0                        8.84       Yes            Poor
# 1199            38.0                       12.69       Yes       Excellent
#
# [1200 rows x 12 columns]
# Shape of the dataset is (1200, 12). This dataset contains 1200 rows and 12 columns.

# %%
movie_rating_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Genre                       1071 non-null   object
#  1   Director_Popularity         1067 non-null   float64
#  2   Budget_MillionUSD           1096 non-null   float64
#  3   Runtime_Minutes             1074 non-null   float64
#  4   Release_Year                1088 non-null   float64
#  5   Num_Main_Actors             1075 non-null   float64
#  6   Avg_Actor_Popularity        1066 non-null   float64
#  7   Has_Famous_Producer         1071 non-null   object
#  8   Num_Awards_Won              1061 non-null   float64
#  9   Marketing_Spend_MillionUSD  1089 non-null   float64
#  10  Is_Sequel                   1083 non-null   object
#  11  Rating_Category             1200 non-null   object
# dtypes: float64(8), object(4)
# memory usage: 112.6+ KB

# %%
features_number = movie_rating_dataframe.shape[1]
print(features_number)
# Out:
# 12

# %%
num_datapoint = movie_rating_dataframe.shape[0]
print(num_datapoint)
# Out:
# 1200

# %%
#Numerical Features
numerical_data = movie_rating_dataframe.select_dtypes(include='number')
numerical_features = numerical_data.columns.tolist()

print(f'There are {len(numerical_features)} numerical features:', '\n')
print(numerical_features)
# Out:
# There are 8 numerical features:
#
# ['Director_Popularity', 'Budget_MillionUSD', 'Runtime_Minutes', 'Release_Year', 'Num_Main_Actors', 'Avg_Actor_Popularity', 'Num_Awards_Won', 'Marketing_Spend_MillionUSD']

# %%
#Categorical Features
categorical_data = movie_rating_dataframe.select_dtypes(include= 'object')
categorical_features=categorical_data.columns.tolist()

print(f'There are {len(categorical_features)} categor features:', '\n')
print(categorical_features)
# Out:
# There are 4 categor features:
#
# ['Genre', 'Has_Famous_Producer', 'Is_Sequel', 'Rating_Category']

# %%
feature_types = movie_rating_dataframe.dtypes
print(feature_types)
# Out:
# Genre                          object
# Director_Popularity           float64
# Budget_MillionUSD             float64
# Runtime_Minutes               float64
# Release_Year                  float64
# Num_Main_Actors               float64
# Avg_Actor_Popularity          float64
# Has_Famous_Producer            object
# Num_Awards_Won                float64
# Marketing_Spend_MillionUSD    float64
# Is_Sequel                      object
# Rating_Category                object
# dtype: object

# %%
numerical_data.describe().T
# Out:
#                              count         mean        std      min  \
# Director_Popularity         1067.0     5.452624   2.600397     1.01
# Budget_MillionUSD           1096.0   152.768723  85.998943     1.04
# Runtime_Minutes             1074.0   129.401304  28.744659    80.00
# Release_Year                1088.0  2002.330882  13.068670  1980.00
# Num_Main_Actors             1075.0     2.531163   1.143236     1.00
# Avg_Actor_Popularity        1066.0     5.495159   2.620555     1.00
# Num_Awards_Won              1061.0    24.113101  14.464153     0.00
# Marketing_Spend_MillionUSD  1089.0    24.351947  14.648245     0.00
#
#                                   25%      50%        75%      max
# Director_Popularity            3.3100     5.40     7.6900    10.00
# Budget_MillionUSD             78.8575   156.06   226.0175   299.73
# Runtime_Minutes              103.0000   130.00   154.0000   179.00
# Release_Year                1991.0000  2002.00  2014.0000  2024.00
# Num_Main_Actors                1.0000     3.00     4.0000     4.00
# Avg_Actor_Popularity           3.2300     5.47     7.8200    10.00
# Num_Awards_Won                12.0000    24.00    37.0000    49.00
# Marketing_Spend_MillionUSD    11.1300    24.43    37.1600    49.98

# %%
categorical_data.describe().T
# Out:
#                     count unique     top freq
# Genre                1071      6  Action  188
# Has_Famous_Producer  1071      2      No  553
# Is_Sequel            1083      2     Yes  554
# Rating_Category      1200      4    Good  324

# %%
numerical_data.var()
# Out:
# Director_Popularity              6.762066
# Budget_MillionUSD             7395.818247
# Runtime_Minutes                826.255394
# Release_Year                   170.790140
# Num_Main_Actors                  1.306989
# Avg_Actor_Popularity             6.867307
# Num_Awards_Won                 209.211724
# Marketing_Spend_MillionUSD     214.571091
# dtype: float64

# %%
numerical_data.skew()
# Out:
# Director_Popularity           0.022995
# Budget_MillionUSD            -0.066930
# Runtime_Minutes              -0.008828
# Release_Year                 -0.015865
# Num_Main_Actors              -0.024278
# Avg_Actor_Popularity         -0.005551
# Num_Awards_Won                0.065543
# Marketing_Spend_MillionUSD    0.041577
# dtype: float64

# %%
#Histogram of all the dataset
numerical_data.hist(figsize=(12,12),bins=20)
plt.show()

# %%
#Boxplot
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = movie_rating_dataframe.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(20, 30))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)
    sns.boxplot(x = movie_rating_dataframe[col], color='skyblue')
    plt.title(f'Boxplot of {col}', fontsize=12)
    plt.tight_layout()

plt.show()

# %%
#Categorical and Quantative Features

categorical_features = []
quantitative_features = []

for col in movie_rating_dataframe.columns:
    if movie_rating_dataframe[col].dtype == 'object':
        categorical_features.append(col)
    elif movie_rating_dataframe[col].dtype in ['int64', 'float64']:
        quantitative_features.append(col)

print(f"Categorical Features: {categorical_features}")
print(f"Quantitative Features: {quantitative_features}")
# Out:
# Categorical Features: ['Genre', 'Has_Famous_Producer', 'Is_Sequel', 'Rating_Category']
# Quantitative Features: ['Director_Popularity', 'Budget_MillionUSD', 'Runtime_Minutes', 'Release_Year', 'Num_Main_Actors', 'Avg_Actor_Popularity', 'Num_Awards_Won', 'Marketing_Spend_MillionUSD']

# %%
movie_rating_dataframe['Genre'].value_counts()
# Out:
# Genre
# Action     188
# Horror     188
# Comedy     178
# Romance    176
# Drama      172
# Sci-Fi     169
# Name: count, dtype: int64

# %%
numerical_data.nunique()
# Out:
# Director_Popularity            626
# Budget_MillionUSD             1079
# Runtime_Minutes                100
# Release_Year                    45
# Num_Main_Actors                  4
# Avg_Actor_Popularity           629
# Num_Awards_Won                  50
# Marketing_Spend_MillionUSD     956
# dtype: int64

# %%
#Null Value Check
print(movie_rating_dataframe.isna().sum())
# Out:
# Genre                         129
# Director_Popularity           133
# Budget_MillionUSD             104
# Runtime_Minutes               126
# Release_Year                  112
# Num_Main_Actors               125
# Avg_Actor_Popularity          134
# Has_Famous_Producer           129
# Num_Awards_Won                139
# Marketing_Spend_MillionUSD    111
# Is_Sequel                     117
# Rating_Category                 0
# dtype: int64

# %%
#Unique Count for each categorical
unique_counts = categorical_data.nunique()
print(unique_counts)
# Out:
# Genre                  6
# Has_Famous_Producer    2
# Is_Sequel              2
# Rating_Category        4
# dtype: int64

# %%
#Categorical Features Histogram
for col in categorical_features:
    plt.title(f'Distribution of {col}')
    categorical_data[col].value_counts().sort_index().plot(kind='bar', rot=0, xlabel=col,ylabel='count')
    plt.show()

# %% [markdown]
# # **Data PreProcessing**

# %%
null_value_rows = movie_rating_dataframe.isnull().any(axis=1).sum()
print(null_value_rows)
# Out:
# 837

# %%
null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)
# Out:
# ['Genre', 'Director_Popularity', 'Budget_MillionUSD', 'Runtime_Minutes', 'Release_Year', 'Num_Main_Actors', 'Avg_Actor_Popularity', 'Has_Famous_Producer', 'Num_Awards_Won', 'Marketing_Spend_MillionUSD', 'Is_Sequel']

# %%
#HeatMap for Null values

import seaborn as sns
sns.heatmap(movie_rating_dataframe.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# # **Preprocessing Starts:**

# %%
#Imputation
'''
if movie_rating_dataframe['Director_Popularity'].isna().any():
    avg_Director_Popularity = movie_rating_dataframe['Director_Popularity'].median()
    movie_rating_dataframe['Director_Popularity'].fillna(avg_Director_Popularity, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Budget_MillionUSD'].isna().any():
    avg_Budget_MillionUSD = movie_rating_dataframe['Budget_MillionUSD'].median()
    movie_rating_dataframe['Budget_MillionUSD'].fillna(avg_Budget_MillionUSD, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Runtime_Minutes'].isna().any():
    avg_runtime = round(movie_rating_dataframe['Runtime_Minutes'].median())  # Round to nearest integer
    movie_rating_dataframe['Runtime_Minutes'].fillna(avg_runtime, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Release_Year'].isna().any():
    is_null_value = movie_rating_dataframe['Release_Year'].isna()
    random_years = np.random.randint(1950, 2026, size = is_null_value.sum())
    movie_rating_dataframe.loc[is_null_value, 'Release_Year'] = random_years
null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

is_null_value = movie_rating_dataframe['Num_Main_Actors'].isna()
num_nulls = is_null_value.sum()

movie_rating_dataframe.loc[is_null_value, 'Num_Main_Actors'] = np.random.choice([1, 2, 3, 4, 5], size=num_nulls)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Avg_Actor_Popularity'].isna().any():
    avg_runtime = round(movie_rating_dataframe['Avg_Actor_Popularity'].median())
    movie_rating_dataframe['Avg_Actor_Popularity'].fillna(avg_runtime, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Avg_Actor_Popularity'].isna().any():
    avg_runtime = round(movie_rating_dataframe['Avg_Actor_Popularity'].median())
    movie_rating_dataframe['Avg_Actor_Popularity'].fillna(avg_runtime, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

has_famous_producer_col = 'Has_Famous_Producer'

if has_famous_producer_col in movie_rating_dataframe.columns:
    movie_rating_dataframe[has_famous_producer_col] = movie_rating_dataframe[has_famous_producer_col].replace({'Yes': 1, 'No': 0})

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

is_null_value = movie_rating_dataframe['Has_Famous_Producer'].isna()
movie_rating_dataframe.loc[is_null_value, 'Has_Famous_Producer'] = np.random.choice([0, 1], size = is_null_value.sum())

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Num_Awards_Won'].isna().any():
    avg_Num_Awards_Won = round(movie_rating_dataframe['Num_Awards_Won'].median())
    movie_rating_dataframe['Num_Awards_Won'].fillna(avg_Num_Awards_Won, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

if movie_rating_dataframe['Marketing_Spend_MillionUSD'].isna().any():
    avg_Budget_MillionUSD = movie_rating_dataframe['Marketing_Spend_MillionUSD'].median()
    movie_rating_dataframe['Marketing_Spend_MillionUSD'].fillna(avg_Budget_MillionUSD, inplace=True)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

Is_Sequel = 'Is_Sequel'

if Is_Sequel in movie_rating_dataframe.columns:
    movie_rating_dataframe[Is_Sequel] = movie_rating_dataframe[Is_Sequel].replace({'Yes': 1, 'No': 0})

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)

is_null_value = movie_rating_dataframe['Is_Sequel'].isna()
movie_rating_dataframe.loc[is_null_value, 'Is_Sequel'] = np.random.choice([0, 1], size = is_null_value.sum())

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)'''
# Out:
# "\nif movie_rating_dataframe['Director_Popularity'].isna().any():\n    avg_Director_Popularity = movie_rating_dataframe['Director_Popularity'].median()\n    movie_rating_dataframe['Director_Popularity'].fillna(avg_Director_Popularity, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Budget_MillionUSD'].isna().any():\n    avg_Budget_MillionUSD = movie_rating_dataframe['Budget_MillionUSD'].median()\n    movie_rating_dataframe['Budget_MillionUSD'].fillna(avg_Budget_MillionUSD, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Runtime_Minutes'].isna().any():\n    avg_runtime = round(movie_rating_dataframe['Runtime_Minutes'].median())  # Round to nearest integer\n    movie_rating_dataframe['Runtime_Minutes'].fillna(avg_runtime, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Release_Year'].isna().any():\n    is_null_value = movie_rating_dataframe['Release_Year'].isna()\n    random_years = np.random.randint(1950, 2026, size = is_null_value.sum())\n    movie_rating_dataframe.loc[is_null_value, 'Release_Year'] = random_years\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nis_null_value = movie_rating_dataframe['Num_Main_Actors'].isna()\nnum_nulls = is_null_value.sum()\n\nmovie_rating_dataframe.loc[is_null_value, 'Num_Main_Actors'] = np.random.choice([1, 2, 3, 4, 5], size=num_nulls)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Avg_Actor_Popularity'].isna().any():\n    avg_runtime = round(movie_rating_dataframe['Avg_Actor_Popularity'].median())\n    movie_rating_dataframe['Avg_Actor_Popularity'].fillna(avg_runtime, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Avg_Actor_Popularity'].isna().any():\n    avg_runtime = round(movie_rating_dataframe['Avg_Actor_Popularity'].median())\n    movie_rating_dataframe['Avg_Actor_Popularity'].fillna(avg_runtime, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nhas_famous_producer_col = 'Has_Famous_Producer'\n\nif has_famous_producer_col in movie_rating_dataframe.columns:\n    movie_rating_dataframe[has_famous_producer_col] = movie_rating_dataframe[has_famous_producer_col].replace({'Yes': 1, 'No': 0})\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nis_null_value = movie_rating_dataframe['Has_Famous_Producer'].isna()\nmovie_rating_dataframe.loc[is_null_value, 'Has_Famous_Producer'] = np.random.choice([0, 1], size = is_null_value.sum())\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Num_Awards_Won'].isna().any():\n    avg_Num_Awards_Won = round(movie_rating_dataframe['Num_Awards_Won'].median())\n    movie_rating_dataframe['Num_Awards_Won'].fillna(avg_Num_Awards_Won, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nif movie_rating_dataframe['Marketing_Spend_MillionUSD'].isna().any():\n    avg_Budget_MillionUSD = movie_rating_dataframe['Marketing_Spend_MillionUSD'].median()\n    movie_rating_dataframe['Marketing_Spend_MillionUSD'].fillna(avg_Budget_MillionUSD, inplace=True)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n\nIs_Sequel = 'I ...

# %%
"""import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Ensure binary columns are treated as object before replacement
binary_mappings = {
    'Has_Famous_Producer': {'Yes': 1, 'No': 0},
    'Is_Sequel': {'Yes': 1, 'No': 0}
}

for col, mapping in binary_mappings.items():
    if col in movie_rating_dataframe.columns:
        movie_rating_dataframe[col] = movie_rating_dataframe[col].astype('object')  # Avoid downcasting warning
        movie_rating_dataframe[col] = movie_rating_dataframe[col].replace(mapping)

# Separate numerical and categorical columns
numerical_cols = movie_rating_dataframe.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = movie_rating_dataframe.select_dtypes(include=['object', 'bool']).columns

# Impute numerical columns with median
num_imputer = SimpleImputer(strategy='median')
movie_rating_dataframe[numerical_cols] = num_imputer.fit_transform(movie_rating_dataframe[numerical_cols])

# Impute categorical columns with most frequent value
cat_imputer = SimpleImputer(strategy='most_frequent')
movie_rating_dataframe[categorical_cols] = cat_imputer.fit_transform(movie_rating_dataframe[categorical_cols])

# Final check
null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print("Remaining columns with nulls:", null_value_cols)
"""
# Out:
# 'import pandas as pd\nimport numpy as np\nfrom sklearn.impute import SimpleImputer\n\n# Ensure binary columns are treated as object before replacement\nbinary_mappings = {\n    \'Has_Famous_Producer\': {\'Yes\': 1, \'No\': 0},\n    \'Is_Sequel\': {\'Yes\': 1, \'No\': 0}\n}\n\nfor col, mapping in binary_mappings.items():\n    if col in movie_rating_dataframe.columns:\n        movie_rating_dataframe[col] = movie_rating_dataframe[col].astype(\'object\')  # Avoid downcasting warning\n        movie_rating_dataframe[col] = movie_rating_dataframe[col].replace(mapping)\n\n# Separate numerical and categorical columns\nnumerical_cols = movie_rating_dataframe.select_dtypes(include=[\'int64\', \'float64\']).columns\ncategorical_cols = movie_rating_dataframe.select_dtypes(include=[\'object\', \'bool\']).columns\n\n# Impute numerical columns with median\nnum_imputer = SimpleImputer(strategy=\'median\')\nmovie_rating_dataframe[numerical_cols] = num_imputer.fit_transform(movie_rating_dataframe[numerical_cols])\n\n# Impute categorical columns with most frequent value\ncat_imputer = SimpleImputer(strategy=\'most_frequent\')\nmovie_rating_dataframe[categorical_cols] = cat_imputer.fit_transform(movie_rating_dataframe[categorical_cols])\n\n# Final check\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint("Remaining columns with nulls:", null_value_cols)\n'

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Drop all rows with any missing values
movie_rating_dataframe.dropna(inplace=True)

# Identify categorical columns
categorical_cols = movie_rating_dataframe.select_dtypes(include=['object', 'bool']).columns

# Encode categorical columns using LabelEncoder
label_encoder = LabelEncoder()
for col in categorical_cols:
    movie_rating_dataframe[col] = label_encoder.fit_transform(movie_rating_dataframe[col].astype(str))

# Final check: confirm no null values remain
null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print("Remaining columns with nulls:", null_value_cols)
# Out:
# Remaining columns with nulls: []

# %%
#Encoding: Categorical Features
'''
import numpy as np

movie_rating_dataframe['Genre'] = movie_rating_dataframe['Genre'].replace({
    'Action': 1,
    'Horror': 2,
    'Comedy': 3,
    'Romance': 4,
    'Drama': 5,
    'Sci-Fi': 6
})


is_null = movie_rating_dataframe['Genre'].isna()
num_nulls = is_null.sum()

movie_rating_dataframe.loc[is_null, 'Genre'] = np.random.choice([1, 2, 3, 4, 5, 6], size=num_nulls)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)
'''
# Out:
# "\nimport numpy as np\n\nmovie_rating_dataframe['Genre'] = movie_rating_dataframe['Genre'].replace({\n    'Action': 1,\n    'Horror': 2,\n    'Comedy': 3,\n    'Romance': 4,\n    'Drama': 5,\n    'Sci-Fi': 6\n})\n\n\nis_null = movie_rating_dataframe['Genre'].isna()\nnum_nulls = is_null.sum()\n\nmovie_rating_dataframe.loc[is_null, 'Genre'] = np.random.choice([1, 2, 3, 4, 5, 6], size=num_nulls)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n"

# %%
movie_rating_dataframe['Rating_Category'].value_counts()
# Out:
# Rating_Category
# 2    109
# 1     93
# 0     87
# 3     74
# Name: count, dtype: int64

# %%
#Encoding
'''
import numpy as np

movie_rating_dataframe['Rating_Category'] = movie_rating_dataframe['Rating_Category'].replace({
    'Good': 1,
    'Excellent': 2,
    'Average': 3,
    'Poor': 4,

})


is_null = movie_rating_dataframe['Rating_Category'].isna()
num_nulls = is_null.sum()

movie_rating_dataframe.loc[is_null, 'Rating_Category'] = np.random.choice([1, 2, 3, 4], size=num_nulls)

null_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()
print(null_value_cols)
'''
# Out:
# "\nimport numpy as np\n\nmovie_rating_dataframe['Rating_Category'] = movie_rating_dataframe['Rating_Category'].replace({\n    'Good': 1,\n    'Excellent': 2,\n    'Average': 3,\n    'Poor': 4,\n\n})\n\n\nis_null = movie_rating_dataframe['Rating_Category'].isna()\nnum_nulls = is_null.sum()\n\nmovie_rating_dataframe.loc[is_null, 'Rating_Category'] = np.random.choice([1, 2, 3, 4], size=num_nulls)\n\nnull_value_cols = movie_rating_dataframe.columns[movie_rating_dataframe.isna().any()].tolist()\nprint(null_value_cols)\n"

# %%
#Coorealation Matrix

import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = movie_rating_dataframe.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='PiYG', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of All Features')
plt.show()

# %%
print(movie_rating_dataframe['Rating_Category'].unique())
# Out:
# [1 3 0 2]

# %%
#Density Plot for Features
numerical_data.plot(kind='density',figsize=(14,14),subplots=True,layout=(15,5),title="Density plot of Numerical features",sharex=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#Target Value Dropped
X = movie_rating_dataframe.drop(columns=['Rating_Category', 'Is_Sequel'])
y = movie_rating_dataframe['Rating_Category']

# %%
#Training and split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify=y, random_state = 60)

# %%
#Conversion True or False
import numpy as np
print(np.unique(y_train))
# Out:
# [0 1 2 3]

# %% [markdown]
# **Model**

# %%
#Logistic Regression
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.23853211009174313
# Confusion Matrix:
#  [[ 6  7 12  1]
#  [ 6  7 15  0]
#  [16  3 13  1]
#  [ 6  4 12  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.18      0.23      0.20        26
#            1       0.33      0.25      0.29        28
#            2       0.25      0.39      0.31        33
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.24       109
#    macro avg       0.19      0.22      0.20       109
# weighted avg       0.20      0.24      0.21       109
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Train Random Forest model
model = RandomForestClassifier(random_state=42)  # You can tune hyperparameters as needed
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.22935779816513763
# Confusion Matrix:
#  [[ 5  7  9  5]
#  [ 4  8 12  4]
#  [ 8 10 12  3]
#  [ 5  5 12  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.23      0.19      0.21        26
#            1       0.27      0.29      0.28        28
#            2       0.27      0.36      0.31        33
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.23       109
#    macro avg       0.19      0.21      0.20       109
# weighted avg       0.20      0.23      0.21       109

# %%
#Logistic Regression
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='PuRd',
            xticklabels=['Good', 'Excellent', 'Average', 'Poor'],
            yticklabels=['Good', 'Excellent', 'Average', 'Poor'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
y_pred_proba = model.predict_proba(x_test)

# %%
#ROC for Logistic Regression
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print(f"Multiclass ROC AUC Score (OvR): {roc_auc:.2f}")
# Out:
# Multiclass ROC AUC Score (OvR): 0.45

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

# Binarize target for multi-class ROC
y_test_bin = label_binarize(y_test, classes=[1, 2, 3, 4])  # Good=1, Excellent=2, Average=3, Poor=4
n_classes = y_test_bin.shape[1]

# Predict probabilities using One-vs-Rest
model_ovr = OneVsRestClassifier(LogisticRegression(max_iter=1000))
model_ovr.fit(x_train, label_binarize(y_train, classes=[1, 2, 3, 4]))
y_score = model_ovr.decision_function(x_test)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(10, 6))
colors = ['blue', 'green', 'orange', 'red']
labels = ['Good', 'Excellent', 'Average', 'Poor']
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=2,
             label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression (One-vs-Rest)')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 3 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.24770642201834864
# Confusion Matrix:
#  [[ 5  6  6  9]
#  [ 7  9  7  5]
#  [ 8  8 12  5]
#  [ 6  6  9  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.19      0.19      0.19        26
#            1       0.31      0.32      0.32        28
#            2       0.35      0.36      0.36        33
#            3       0.05      0.05      0.05        22
#
#     accuracy                           0.25       109
#    macro avg       0.23      0.23      0.23       109
# weighted avg       0.24      0.25      0.25       109

# %%
#Confusion Matrix for Decision Tree Classifier
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='PuRd',
            xticklabels=['Good', 'Excellent', 'Average', 'Poor'],
            yticklabels=['Good', 'Excellent', 'Average', 'Poor'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
#ROC AOC Score
y_pred_proba = model.predict_proba(x_test)
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print(f"Multiclass ROC AUC Score (OvR): {roc_auc:.2f}")
# Out:
# Multiclass ROC AUC Score (OvR): 0.49

# %%
#Neural Network

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
model = MLPClassifier(hidden_layer_sizes=(128,100,50), activation='relu', solver='adam',
                      max_iter=10000, batch_size=5, random_state=42)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.30275229357798167
# Confusion Matrix:
#  [[ 0  0 26  0]
#  [ 0  0 28  0]
#  [ 0  0 33  0]
#  [ 0  0 22  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.00      0.00      0.00        28
#            2       0.30      1.00      0.46        33
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.30       109
#    macro avg       0.08      0.25      0.12       109
# weighted avg       0.09      0.30      0.14       109
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt

plt.plot(model.loss_curve_)
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC


# Define models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "SVM (probability)": SVC(probability=True),

}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Neural Network": MLPClassifier(max_iter=1000, random_state=42)
}

plt.figure(figsize=(18, 6))  # 1 row, 3 columns for 3 models

for i, (name, model) in enumerate(models.items(), 1):
    # Fit the model
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)

    # Plot confusion matrix
    plt.subplot(1, 3, i)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"{name}\nAccuracy: {acc:.2f}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'hidden_layer_sizes': [(128, 100, 50), (100, 50), (64, 32)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'batch_size': [5, 10],
    'max_iter': [5000]  # Lowered for speed; you can increase if needed
}

# Create MLPClassifier
mlp = MLPClassifier(random_state=42)

# Apply GridSearchCV
grid_search = GridSearchCV(mlp, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
grid_search.fit(x_train, y_train)

# Best model
best_model = grid_search.best_estimator_

# Predictions
y_pred = best_model.predict(x_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Best Parameters:", grid_search.best_params_)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'activation': 'relu', 'batch_size': 5, 'hidden_layer_sizes': (64, 32), 'max_iter': 5000, 'solver': 'sgd'}
# Accuracy: 0.30275229357798167
# Confusion Matrix:
#  [[ 0  0 26  0]
#  [ 0  0 28  0]
#  [ 0  0 33  0]
#  [ 0  0 22  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.00      0.00      0.00        28
#            2       0.30      1.00      0.46        33
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.30       109
#    macro avg       0.08      0.25      0.12       109
# weighted avg       0.09      0.30      0.14       109
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'hidden_layer_sizes': [(128, 100, 50), (100, 50), (64, 32)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'batch_size': [5, 10],
    'max_iter': [5000]  # Lowered for speed; you can increase if needed
}

# Create MLPClassifier
mlp = MLPClassifier(random_state=42)

# Apply GridSearchCV
grid_search = GridSearchCV(mlp, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
grid_search.fit(x_train, y_train)

# Best model
best_model = grid_search.best_estimator_

# Predictions
y_pred = best_model.predict(x_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Best Parameters:", grid_search.best_params_)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'activation': 'relu', 'batch_size': 5, 'hidden_layer_sizes': (64, 32), 'max_iter': 5000, 'solver': 'sgd'}
# Accuracy: 0.30275229357798167
# Confusion Matrix:
#  [[ 0  0 26  0]
#  [ 0  0 28  0]
#  [ 0  0 33  0]
#  [ 0  0 22  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.00      0.00      0.00        28
#            2       0.30      1.00      0.46        33
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.30       109
#    macro avg       0.08      0.25      0.12       109
# weighted avg       0.09      0.30      0.14       109
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
